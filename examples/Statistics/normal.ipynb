# %%
from sympy.stats import Expectation, Normal, Probability, Poisson,MultivariateNormal, density, marginal_distribution,P,correlation,given
from sympy.stats import cdf,variance,Variance
from sympy import symbols, Integral, Sum,MatrixSymbol,Matrix,simplify,expand,Eq,Symbol

# %%
mu = Symbol("mu")
sigma = Symbol("sigma", positive=True)

z = Symbol("z")
y = Symbol("y")
p = Symbol("p")
X = Normal("x", mu, sigma)

density(X)
# Out:
# NormalDistribution(mu, sigma)

# %%
density(X)(x)
# Out:
# sqrt(2)*exp(-(1 - mu)**2/(2*sigma**2))/(2*sqrt(pi)*sigma)

# %%
cdf(X)(y)
# Out:
# erf(sqrt(2)*(-mu + y)/(2*sigma))/2 + 1/2

# %%
dist = Normal("x", 0,1)

# %%
density(dist)(z)
# Out:
# sqrt(2)*exp(-z**2/2)/(2*sqrt(pi))

# %%
Expectation(dist)
# Out:
# Expectation(x)

# %%
Variance(dist)
# Out:
# Variance(x)
