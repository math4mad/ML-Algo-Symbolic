# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
from sympy import *

# %%
y = Function('y')
t=Symbol('t')
dsolve(Eq(y(t).diff(t, t) - y(t), exp(t)), y(t))
# Out:
# Eq(y(t), C2*exp(-t) + (C1 + t/2)*exp(t))

# %%
f=Function('f')
x=Symbol('x')
expr=x**2
func=Eq(f(x),x**2)
func
# Out:
# Eq(f(x), x**2)

# %%
f(2)
# Out:
# f(2)

# %%
Eq(f(2),fx(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Eq(f(2),fx(2))
#
# NameError: name 'fx' is not defined

# %%
def fexpr(num):
    return Eq(f(num),fx(num))

# %%
 fexpr(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fexpr(2)
#
# Cell In[14], line 2, in fexpr(num)
#       1 def fexpr(num):
# ----> 2     return Eq(f(num),fx(num))
#
# NameError: name 'fx' is not defined

# %%
fexpr(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fexpr(4)
#
# Cell In[16], line 2, in fexpr(num)
#       1 def fexpr(num):
# ----> 2     return Eq(f(num),fx(num))
#
# NameError: name 'fx' is not defined

# %%
from sympy.abc import x, y, z
f = lambdify([(x, y, z)], Eq(z**2, x**2 + y**2))
f
# Out:
# <function _lambdifygenerated(_Dummy_52)>

# %%
#f = implemented_function(Function('f'), lambda x: x+1)
